# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from utils import load_dataset, train_test_split
from LR import Model

# %%
df = pd.read_csv("./dataset_LR.csv")
df.describe()
# Out:
#              attr1        attr2        attr3        attr4        class
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
X, y = load_dataset("./dataset_LR.csv")

# %%
training, testing = train_test_split(X, y)

# %%
model = Model(X.shape[1], 'Random')
cost, accuracy = model.bgd(training["X"].T, training["y"].T, lr=0.05)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 5790.13it/s]

# %%
model.W, model.b
# Out:
# (array([[-1.77791466],
#         [-1.0403826 ],
#         [-1.17994633],
#         [-0.21577592]]),
#  1.6413477629960462)

# %%
plt.plot(accuracy)
plt.plot(cost)

# %%
metrics = model.test(testing["X"].T, testing["y"].T)
metrics
# Out:
# {'epochs': 50,
#  'accuracy': 0.9830097087378641,
#  'precision': 0.9828571428571429,
#  'recall': 0.9772727272727273,
#  'f1-score': 0.98005698005698}

# %%
X, y = load_dataset("./dataset_LR.csv")

# %%
X_min = X.min(axis=0)
X_max = X.max(axis=0)

# %%
X = (X - X_min) / (X_max - X_min)

# %%
X.mean(axis=0)
# Out:
# array([0.53911366, 0.58730138, 0.28792414, 0.66891654])

# %%
X.std(axis=0)
# Out:
# array([0.20492874, 0.21953128, 0.18560144, 0.19097151])

# %%
plt.plot(X[:, 3])

# %%
training, testing = train_test_split(X, y)

# %%
model = Model(X.shape[1], 'Random')
cost, accuracy = model.bgd(training["X"].T, training["y"].T, lr=0.85)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 6071.77it/s]

# %%
model.W, model.b
# Out:
# (array([[-11.61619029],
#         [ -5.44408003],
#         [ -6.03323257],
#         [  2.44542804]]),
#  9.090619587160345)

# %%
plt.plot(accuracy)
plt.plot(cost)

# %%
metrics = model.test(testing["X"].T, testing["y"].T)

# %%
metrics
# Out:
# {'epochs': 1000,
#  'accuracy': 0.9635922330097088,
#  'precision': 0.9651162790697675,
#  'recall': 0.9485714285714286,
#  'f1-score': 0.9567723342939481}

# %%
X, y = load_dataset("./dataset_LR.csv")

# %%
mu = X.mean(axis=0)
sigma = X.std(axis=0)

# %%
X -= mu
X /= sigma

# %%
X.mean(axis=0)
# Out:
# array([-1.68313695e-17,  1.81260902e-17,  1.03577658e-17, -5.43782706e-17])

# %%
X.std(axis=0)
# Out:
# array([1., 1., 1., 1.])

# %%
training, testing = train_test_split(X, y)

# %%
model = Model(X.shape[1], 'Random')
cost, accuracy = model.bgd(training["X"].T, training["y"].T, lr=0.95)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 6543.49it/s]

# %%
model.W, model.b
# Out:
# (array([[-5.80888214],
#         [-6.54805442],
#         [-5.80523014],
#         [ 0.03034108]]),
#  -2.090170223859082)

# %%
plt.plot(accuracy)
plt.plot(cost)

# %%
metrics = model.test(testing["X"].T, testing["y"].T)
metrics
# Out:
# {'epochs': 1000,
#  'accuracy': 0.9830097087378641,
#  'precision': 0.9593023255813954,
#  'recall': 1.0,
#  'f1-score': 0.9792284866468842}
